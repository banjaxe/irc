# %% [markdown]
# <a href="https://colab.research.google.com/github/banjaxe/irc/blob/master/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook free google colab!
# ## 🌟 Features
#
# - 📖 Converts eBooks to text format with Calibre.
# - 📚 Splits eBook into chapters for organized audio.
# - 🎙️ High-quality text-to-speech with [Coqui XTTS](https://huggingface.co/coqui/XTTS-v2), [Fairseq](https://github.com/facebookresearch/fairseq), [Bark](https://github.com/suno-ai/bark), [Vits](https://github.com/jaywalnut310/vits), and [Yourtts](https://github.com/Edresson/YourTTS).
# - 🗣️ Optional voice cloning with your own voice file or choose from our pre-made fine-tuned models!
# - 🌍 Supports multiple languages! Arabic (ar), Chinese (zh-cn), Czech (cs), Dutch (nl), English (en), French (fr), German (de), Hindi (hi), Hungarian (hu), Italian (it), Japanese (ja), Korean (ko), Polish (pl), Portuguese (pt), Russian (ru), Spanish (es), Turkish (tr), Vietnamese (vi), [+ 1107 languages via Fairseq](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html)
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🚀 Run ebook2audiobook!

import os
import re
import subprocess
import time  # Import the time module
from IPython.display import HTML, display
import pkg_resources  # For checking installed packages

# Emojis for logs
CHECK_MARK = "✅"
CROSS_MARK = "❌"

def display_loading_bar(total_steps):
    """Displays a more visual text-based loading indicator in Colab."""
    print("\n---  LOADING...  Total steps:", total_steps, " ---") # Separator and loading start

def update_progress(step, total_steps):
  """Updates the text-based loading indicator with a bar-like style."""
  bar_length = 20  # Length of the "bar"
  progress_percent = int((step / total_steps) * 100)
  progress_filled = int(bar_length * step / total_steps)
  bar = '=' * progress_filled + '>' + ' ' * (bar_length - progress_filled -1 if (bar_length - progress_filled -1) >= 0 else 0) # Handle potential index error
  progress_text = f"[{bar}] {progress_percent}% ({step}/{total_steps})"
  print(f"---  PROGRESS:  {progress_text} ---") # Separator for progress update

def run_command_with_log(command, description, step_progress, total_step_commands):
    """Runs a command and logs its progress and outcome with emojis and duration."""
    print(f"\n{step_progress}/{total_step_commands}: {description}...")
    start_time = time.time()  # Record start time
    try:
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()
        end_time = time.time()  # Record end time
        duration = end_time - start_time # Calculate duration
        duration_formatted = "{:.2f}".format(duration) # Format duration to 2 decimal places

        if process.returncode != 0:
            print(f"{CROSS_MARK} Command failed: {description} (Took {duration_formatted} seconds)")
            print(f"   Command: {command}")
            print(f"   Error Output:\n{stderr.decode()}")
            return False
        else:
            update_progress(step_progress, total_step_commands) # Use updated progress function
            print(f"{CHECK_MARK} Command {step_progress}/{total_step_commands} completed: {description} (Took {duration_formatted} seconds)")
            return True

    except Exception as e:
        end_time = time.time()  # Record end time even if exception occurs
        duration = end_time - start_time # Calculate duration
        duration_formatted = "{:.2f}".format(duration) # Format duration
        print(f"{CROSS_MARK} A general error occurred during command: {description} (Took {duration_formatted} seconds)")
        print(f"   Error: {e}")
        return False

# --- Step 1: OS-Level Installations ---
os_install_commands = [
    ("sudo apt-get update", "Updating software package lists (Takes around 14.14 seconds)"),
    ("apt-get install -y libxcb-cursor0", "Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds)"),
    ("sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin", "Download & install Calibre ebook manager(Takes around 29.40 seconds)"),
    ("apt-get install -y libegl1", "Install graphics library (libegl1) (Takes around 4.12 seconds)"),
    ("apt-get install -y libopengl0", "Install graphics library (libopengl0) (Takes around 3.07 seconds)"),
    ("apt-get install -y ffmpeg", "Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds)"),
    ("apt-get install -y mecab", "Install mecab (Japanese text analysis) (Takes around 14.51 seconds)"),
    ("apt-get install -y libmecab-dev", "Install mecab development files (Takes around 5.72 seconds)"),
    ("apt-get install -y mecab-ipadic-utf8", "Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds)"),
    ("apt-get install -y nodejs", "Install nodejs (Javascript runtime) (Takes around 7.03 seconds)"),
    ("pip install mecab-python3 unidic-lite", "Install mecab-python3 (Takes around 19.80 seconds)"),
    ("pip install unidic-lite", "Install lightweight unidic dictionary (Takes around 2.15 seconds)"),
    ("pip install unidic", "Install full Unidic dictionary (Takes around 4.00 seconds)"),
    ("python -m unidic download", "Download Unidic dictionary data (Takes around 29.05 seconds)"),
]
os_install_completed = False

# --- Step 2: Git Clone & Requirements ---
git_requirements_commands = [
    ("git clone https://github.com/DrewThomasson/ebook2audiobook.git", "Git clone Ebook2audiobook"),
    ("pip install -r /content/ebook2audiobook/requirements.txt", "Install Python requirements (Takes around 202.4 seconds)"),
]
git_requirements_completed = False

# --- Step 3: Run App ---
run_app_completed = False


# --- Step 1 Execution ---
if os_install_completed:
    print("\nStep 1: OS-Level Installations - Already completed, skipping.")
else:
    print("\n--- Step 1: OS-Level Installations ---")
    print("This step installs essential software on the Colab system. (Takes around 3-4 minutes)")
    total_steps_step1 = len(os_install_commands)
    display_loading_bar(total_steps_step1) # Start enhanced loading indicator

    step1_success = True
    for i, (command, description) in enumerate(os_install_commands):
        if not run_command_with_log(command, description, i + 1, total_steps_step1):
            step1_success = False
            break

    if step1_success:
        os_install_completed = True
        print(f"\n{CHECK_MARK} Step 1: OS-Level Installations - Completed Successfully!")
    else:
        print(f"\n{CROSS_MARK} Step 1: OS-Level Installations - Failed. See error messages above.")


# --- Step 2 Execution ---
if git_requirements_completed:
    print("\nStep 2: Git Clone & Requirements - Already completed, skipping.")
else:
    print("\n--- Step 2: Git Clone & Requirements ---")
    print("This step downloads program files and installs Python components. (Takes around 3-4 minutes)")
    total_steps_step2 = len(git_requirements_commands)
    display_loading_bar(total_steps_step2) # Start enhanced loading indicator

    step2_success = True
    for i, (command, description) in enumerate(git_requirements_commands):
        if not run_command_with_log(command, description, i + 1, total_steps_step2):
            step2_success = False
            break

    if step2_success:
        git_requirements_completed = True
        print(f"\n{CHECK_MARK} Step 2: Git Clone & Requirements - Completed Successfully!")
    else:
        print(f"\n{CROSS_MARK} Step 2: Git Clone & Requirements - Failed. See error messages above.")


def modify_python_version(filepath, new_version=(3, 11)):
    """
    Modifies the min_python_version in a Python file.
    (Function definition - same as before)
    """
    try:
        with open(filepath, 'r') as f:
            file_content = f.read()
        pattern = r"min_python_version = \(\s*(\d+)\s*,\s*(\d+)\s*\)"
        def replacement(match):
            return f"min_python_version = ({new_version[0]}, {new_version[1]})"
        new_content = re.sub(pattern, replacement, file_content)
        if new_content != file_content:
            with open(filepath, 'w') as f:
                f.write(new_content)
            print(f"Successfully changed min_python_version in {filepath} to {new_version}")
        else:
            print(f"min_python_version in {filepath} was already {new_version} or not found.")
    except FileNotFoundError:
        print(f"Error: File not found: {filepath}")
    except Exception as e:
        print(f"An error occurred: {e}")

def fix_functions_py(filepath):
    """
    Scans functions.py and fixes the incorrect f-string issue if found.
    """
    # Define the incorrect pattern (allowing indentation and triple quotes)
    incorrect_pattern = r"msg\s*=\s*f'Voice file \{re\.sub\(r'_\(24000\|16000\)\\.wav\$', '', selected_name\)\} deleted!'"

    # Correct replacement (keeping indentation)
    correct_replacement = """                        cleaned_name = re.sub(r'_(24000|16000)\\.wav$', '', selected_name)
                        msg = f"Voice file {cleaned_name} deleted!" """

    try:
        # Read the file
        with open(filepath, "r") as file:
            lines = file.readlines()

        # Check and replace the incorrect line
        modified_lines = []
        fixed = False

        for line in lines:
            if re.search(incorrect_pattern, line.strip()):  # Use regex search instead of exact match
                print("🔍 Found incorrect line in functions.py. Fixing it now...")
                modified_lines.append(correct_replacement + "\n")  # Add the corrected version
                fixed = True
            else:
                modified_lines.append(line)  # Keep other lines unchanged

        # Only overwrite the file if a fix was applied
        if fixed:
            with open(filepath, "w") as file:
                file.writelines(modified_lines)
            print("✅ Fix applied successfully!")
        else:
            print("✅ No fix needed. The exact error line was not found.")

    except FileNotFoundError:
        print(f"❌ Error: The file {filepath} was not found.")
    except Exception as e:
        print(f"❌ An error occurred: {e}")

# Modify conf.py AFTER git clone (Step 2 ensures clone is done)
filepath = "/content/ebook2audiobook/lib/conf.py"
modify_python_version(filepath)

# Call the function to fix functions.py
filepath = "/content/ebook2audiobook/lib/functions.py"
fix_functions_py(filepath)




# --- Step 3 Execution ---
if run_app_completed:
    print("\nStep 3: Run App - Already run (or skipped).")
else:
    print("\n--- Step 3: Run App ---")
    print("This step starts the ebook2audiobook web interface.")
    print("Starting ebook2audiobook...")
    try:
        # !cd ebook2audiobook && python app.py --script_mode full_docker --share
        run_app_completed = True
    except Exception as e:
        print(f"{CROSS_MARK} Error starting app.py: {e}")
    else:
        print(f"\n{CHECK_MARK} Step 3: Run App - Started! Check the output above for the Gradio link.")


print("\n--- All Steps Initiated (or Skipped if Already Run) ---")
print("Check the output above for details on each step.")
# Out:
# <ipython-input-1-7d3eb022bfc4>:8: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources  # For checking installed packages
# --- Step 1: OS-Level Installations ---
# This step installs essential software on the Colab system. (Takes around 3-4 minutes)
#
# ---  LOADING...  Total steps: 14  ---
#
# 1/14: Updating software package lists (Takes around 14.14 seconds)...
# ---  PROGRESS:  [=>                  ] 7% (1/14) ---
# ✅ Command 1/14 completed: Updating software package lists (Takes around 14.14 seconds) (Took 10.39 seconds)
#
# 2/14: Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds)...
# ---  PROGRESS:  [==>                 ] 14% (2/14) ---
# ✅ Command 2/14 completed: Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds) (Took 11.24 seconds)
#
# 3/14: Download & install Calibre ebook manager(Takes around 29.40 seconds)...
# ---  PROGRESS:  [====>               ] 21% (3/14) ---
# ✅ Command 3/14 completed: Download & install Calibre ebook manager(Takes around 29.40 seconds) (Took 29.86 seconds)
#
# 4/14: Install graphics library (libegl1) (Takes around 4.12 seconds)...
# ---  PROGRESS:  [=====>              ] 28% (4/14) ---
# ✅ Command 4/14 completed: Install graphics library (libegl1) (Takes around 4.12 seconds) (Took 2.73 seconds)
#
# 5/14: Install graphics library (libopengl0) (Takes around 3.07 seconds)...
# ---  PROGRESS:  [=======>            ] 35% (5/14) ---
# ✅ Command 5/14 completed: Install graphics library (libopengl0) (Takes around 3.07 seconds) (Took 2.85 seconds)
#
# 6/14: Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds)...
# ---  PROGRESS:  [========>           ] 42% (6/14) ---
# ✅ Command 6/14 completed: Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds) (Took 2.76 seconds)
#
# 7/14: Install mecab (Japanese text analysis) (Takes around 14.51 seconds)...
# ---  PROGRESS:  [==========>         ] 50% (7/14) ---
# ✅ Command 7/14 completed: Install mecab (Japanese text analysis) (Takes around 14.51 seconds) (Took 14.01 seconds)
#
# 8/14: Install mecab development files (Takes around 5.72 seconds)...
# ---  PROGRESS:  [===========>        ] 57% (8/14) ---
# ✅ Command 8/14 completed: Install mecab development files (Takes around 5.72 seconds) (Took 5.08 seconds)
#
# 9/14: Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds)...
# ---  PROGRESS:  [============>       ] 64% (9/14) ---
# ✅ Command 9/14 completed: Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds) (Took 9.99 seconds)
#
# 10/14: Install nodejs (Javascript runtime) (Takes around 7.03 seconds)...
# ---  PROGRESS:  [==============>     ] 71% (10/14) ---
# ✅ Command 10/14 completed: Install nodejs (Javascript runtime) (Takes around 7.03 seconds) (Took 6.38 seconds)
#
# 11/14: Install mecab-python3 (Takes around 19.80 seconds)...
# ---  PROGRESS:  [===============>    ] 78% (11/14) ---
# ✅ Command 11/14 completed: Install mecab-python3 (Takes around 19.80 seconds) (Took 21.04 seconds)
#
# 12/14: Install lightweight unidic dictionary (Takes around 2.15 seconds)...
# ---  PROGRESS:  [=================>  ] 85% (12/14) ---
# ✅ Command 12/14 completed: Install lightweight unidic dictionary (Takes around 2.15 seconds) (Took 2.20 seconds)
#
# 13/14: Install full Unidic dictionary (Takes around 4.00 seconds)...
# ---  PROGRESS:  [==================> ] 92% (13/14) ---
# ✅ Command 13/14 completed: Install full Unidic dictionary (Takes around 4.00 seconds) (Took 4.32 seconds)
#
# 14/14: Download Unidic dictionary data (Takes around 29.05 seconds)...
# ---  PROGRESS:  [====================>] 100% (14/14) ---
# ✅ Command 14/14 completed: Download Unidic dictionary data (Takes around 29.05 seconds) (Took 30.61 seconds)
#
# ✅ Step 1: OS-Level Installations - Completed Successfully!
#
# --- Step 2: Git Clone & Requirements ---
# This step downloads program files and installs Python components. (Takes around 3-4 minutes)
#
# ---  LOADING...  Total steps: 2  ---
#
# 1/2: Git clone Ebook2audiobook...
# ---  PROGRESS:  [==========>         ] 50% (1/2) ---
# ✅ Command 1/2 completed: Git clone Ebook2audiobook (Took 11.31 seconds)
#
# 2/2: Install Python requirements (Takes around 202.4 seconds)...
# ---  PROGRESS:  [====================>] 100% (2/2) ---
# ✅ Command 2/2 completed: Install Python requirements (Takes around 202.4 seconds) (Took 197.71 seconds)
#
# ✅ Step 2: Git Clone & Requirements - Completed Successfully!
# Successfully changed min_python_version in /content/ebook2audiobook/lib/conf.py to (3, 11)
# 🔍 Found incorrect line in functions.py. Fixing it now...
# ✅ Fix applied successfully!
#
# --- Step 3: Run App ---
# This step starts the ebook2audiobook web interface.
# Starting ebook2audiobook...
# 2025-03-04 00:37:45.154322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741048665.418885    4206 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741048665.491890    4206 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 00:37:46.056405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# IPs available for connection:
# ['127.0.0.1', '172.28.0.12']
# Note: 0.0.0.0 is not the IP to connect. Instead use an IP above to connect.
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://49b55d417b123314ae.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing eBook file: Eric Harry - Arc Light - 9781476737690.epub
# Available Processor Unit: cuda
# Running command: /usr/bin/ebook-convert /content/ebook2audiobook/tmp/ebook-343aacdb-c27d-416d-9dc1-6dc245a73c6a/afd325c25dd1d4571a6fae359a148b3a/Eric Harry - Arc Light - 9781476737690.epub /content/ebook2audiobook/tmp/ebook-343aacdb-c27d-416d-9dc1-6dc245a73c6a/afd325c25dd1d4571a6fae359a148b3a/__Eric Harry - Arc Light - 9781476737690.epub --input-encoding=utf-8 --output-profile=generic_eink --verbose
# Conversion options changed from defaults:
#   verbose: 1
#   output_profile: 'generic_eink'
#   input_encoding: 'utf-8'
# 1% Converting input to HTML...
# InputFormatPlugin: EPUB Input running
# on /content/ebook2audiobook/tmp/ebook-343aacdb-c27d-416d-9dc1-6dc245a73c6a/afd325c25dd1d4571a6fae359a148b3a/Eric Harry - Arc Light - 9781476737690.epub
# Found HTML cover OEBPS/Text/cover.html
# Parsing all content...
# Parsing OEBPS/Text/ch19.html ...
# Parsing OEBPS/Text/ch05a.html ...
# Parsing OEBPS/Text/ch12a.html ...
# Parsing OEBPS/Text/ch02.html ...
# Parsing OEBPS/Text/cover.html ...
# Parsing OEBPS/Text/part01.html ...
# Parsing OEBPS/Styles/9781476737690.css ...
# Parsing OEBPS/Text/ebookregfront.html ...
# Parsing OEBPS/Text/title.html ...
# Parsing OEBPS/Text/ch03.html ...
# Parsing OEBPS/Text/ch12b.html ...
# Parsing OEBPS/Text/epilogue.html ...
# Parsing OEBPS/Text/ch04.html ...
# Parsing OEBPS/Text/ch06.html ...
# Parsing OEBPS/Text/ack.html ...
# Parsing OEBPS/Text/fm02.html ...
# Parsing OEBPS/Text/ch12c.html ...
# Parsing OEBPS/Text/ch05b.html ...
# Parsing OEBPS/Text/part03.html ...
# Parsing OEBPS/Text/ch12d.html ...
# Parsing OEBPS/Text/ch17.html ...
# Parsing OEBPS/Text/ch16a.html ...
# Parsing OEBPS/Text/copyright.html ...
# Parsing OEBPS/Text/ch07.html ...
# Parsing OEBPS/Text/part05.html ...
# Parsing OEBPS/Text/ch13.html ...
# Parsing OEBPS/Text/ch08.html ...
# Parsing OEBPS/Text/ch18.html ...
# Parsing OEBPS/Text/ch14.html ...
# Parsing OEBPS/Text/ch09.html ...
# Parsing OEBPS/Text/Prologue.html ...
# Parsing OEBPS/Text/contents.html ...
# Parsing OEBPS/Text/ch01.html ...
# Parsing OEBPS/Text/dedi.html ...
# Parsing OEBPS/Text/part02.html ...
# Parsing OEBPS/Text/part04.html ...
# Parsing OEBPS/Text/ch15a.html ...
# Parsing OEBPS/Text/Epigraph.html ...
# Parsing OEBPS/Text/ch10.html ...
# Parsing OEBPS/Text/ch15b.html ...
# Parsing OEBPS/Text/ch16b.html ...
# Parsing OEBPS/Text/ebookregback.html ...
# Parsing OEBPS/Text/ch15.html ...
# Parsing OEBPS/Text/ch11.html ...
# Parsing OEBPS/Text/ch16.html ...
# Parsing OEBPS/Text/ch05.html ...
# Parsing OEBPS/Text/ch12.html ...
# Reading TOC from NCX...
# 34% Running transforms on e-book...
# Merging user specified metadata...
# Detecting structure...
# 	Detected chapter: PROLOGUE
# 	Detected chapter: PART ONE
# 	Detected chapter: PART TWO
# 	Detected chapter: PART THREE
# 	Detected chapter: PART FOUR
# 	Detected chapter: PART FIVE
# 	Detected chapter: EPILOGUE
# Flattening CSS and remapping font sizes...
# Source base font size is 12.00000pt
# Removing fake margins...
# Found 13 items of level: div_1
# Found 6 items of level: p_2
# Found 2 items of level: div_2
# Found 2 items of level: p_3
# Found 5044 items of level: p_1
# Ignoring level p_3
# Ignoring level p_2
# div_1  left margin stats: Counter()
# div_1  right margin stats: Counter()
# div_2  left margin stats: Counter()
# div_2  right margin stats: Counter()
# Negative text indent detected at level  p_1, ignoring this level
# Removing page margins specified in the Adobe page template
# Cleaning up manifest...
# Trimming unused files from manifest...
# Creating EPUB Output...
# 67% Running EPUB Output plugin
# Splitting markup on page breaks and flow limits, if any...
# 	Looking for large trees in OEBPS/Text/ch19.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch05a.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch12a.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch02.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/part01.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/ebookregfront.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/title.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch03.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch12b.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/epilogue.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/ch04.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch06.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ack.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/fm02.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch12c.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch05b.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/part03.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/ch12d.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch17.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch16a.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/copyright.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch07.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/part05.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/ch13.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch08.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch18.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch14.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch09.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/Prologue.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/contents.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch01.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/dedi.html...
# 	No large trees found
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/part02.html...
# 	No large trees found
# 	Split into 2 parts
# 		Splitting on page-break at id=calibre_pb_0
# 	Looking for large trees in OEBPS/Text/part04.html...
# 	No large trees found
# 	Split into 2 parts
# 	Looking for large trees in OEBPS/Text/ch15a.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/Epigraph.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch10.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch15b.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch16b.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ebookregback.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch15.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch11.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch16.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch05.html...
# 	No large trees found
# 	Looking for large trees in OEBPS/Text/ch12.html...
# 	No large trees found
# Removing anchor from TOC href: OEBPS/Text/part01_split_001.html#part01
# Removing anchor from TOC href: OEBPS/Text/part02_split_001.html#part02
# Removing anchor from TOC href: OEBPS/Text/part03_split_001.html#part03
# Removing anchor from TOC href: OEBPS/Text/part04_split_001.html#part04
# Removing anchor from TOC href: OEBPS/Text/part05_split_001.html#part05
# Removing anchor from TOC href: OEBPS/Text/epilogue_split_001.html#epi
# The cover image has an id != "cover". Renaming to work around bug in Nook Color
# EPUB output written to /content/ebook2audiobook/tmp/ebook-343aacdb-c27d-416d-9dc1-6dc245a73c6a/afd325c25dd1d4571a6fae359a148b3a/__Eric Harry - Arc Light - 9781476737690.epub
# Output saved to   /content/ebook2audiobook/tmp/ebook-343aacdb-c27d-416d-9dc1-6dc245a73c6a/afd325c25dd1d4571a6fae359a148b3a/__Eric Harry - Arc Light - 9781476737690.epub
#
# /usr/local/lib/python3.11/dist-packages/ebooklib/epub.py:1423: FutureWarning: This search incorrectly ignores the root element, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/xmlns:rootfile[@media-type]'
#   for root_file in tree.findall('//xmlns:rootfile[@media-type]', namespaces={'xmlns': NAMESPACES['CONTAINERNS']}):
# ******* NOTE: YOU CAN SAFELY IGNORE "Character xx not found in the vocabulary." *******
# Loading TTS tts_models/multilingual/multi-dataset/xtts_v2 model, it takes a while, please be patient...
# /usr/local/lib/python3.11/dist-packages/TTS/api.py:92: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
# 100% 1.86G/1.87G [00:26<00:00, 79.9MiB/s]
# 100% 1.87G/1.87G [00:26<00:00, 69.7MiB/s]
# 100% 4.37k/4.37k [00:00<00:00, 37.6kiB/s]
#  55% 198k/361k [00:00<00:00, 1.45MiB/s]
# 100% 361k/361k [00:00<00:00, 1.42MiB/s]
# 100% 32.0/32.0 [00:00<00:00, 160iB/s]
# 100% 7.75M/7.75M [00:12<00:00, 16.0MiB/s]
# convertsion 0.00%:   0% 0/11950 [00:00<?, ?step/s]Block 1 containing 808 sentences...
#
# Converting 0.00%:   0% 0/11950 [00:09<?, ?step/s]
# Sentence: CHAPTER ONE . THE PENTAGON , OUTSIDE WASHINGTON , D . C . June 11,
#
# Converting 0.00%:   0% 1/11950 [00:09<30:16:18,  9.12s/step]
# Converting 0.01%:   0% 1/11950 [00:14<30:16:18,  9.12s/step]
# Sentence: 04 30 GMT (23 30 Local) A single red light blinked on the desk phone's panel of twenty separate lines . It was not ,
#
# Converting 0.01%:   0% 2/11950 [00:14<23:39:42,  7.13s/step]
# Converting 0.02%:   0% 2/11950 [00:19<23:39:42,  7.13s/step]
# Sentence: General Andrew Thomas made sure , the President , the Pacific Command , or any of the other dedicated lines along the bottom row .
#
# Converting 0.02%:   0% 3/11950 [00:19<19:53:25,  5.99s/step]
# Converting 0.03%:   0% 3/11950 [00:23<19:53:25,  5.99s/step]
# Sentence: It was just an ordinary outside line . Thomas , chairman of the Joint Chiefs of Staff ,
#
# Converting 0.03%:   0% 4/11950 [00:23<17:45:12,  5.35s/step]
# Converting 0.03%:   0% 4/11950 [00:28<17:45:12,  5.35s/step]
# Sentence: rubbed his bleary eyes and returned to the logistics report from Eighth Army Command that lay in a puddle of light beneath his desk lamp .
#
# Converting 0.03%:   0% 5/11950 [00:28<16:26:56,  4.96s/step]
# Converting 0.04%:   0% 5/11950 [00:31<16:26:56,  4.96s/step]
# Sentence: Not the time for sleep , Thomas thought , yawning . I can sleep after the war .
#
# Converting 0.04%:   0% 6/11950 [00:31<15:10:09,  4.57s/step]
# Converting 0.05%:   0% 6/11950 [00:35<15:10:09,  4.57s/step]
# Sentence: His eyes strayed up to the map table across the plush , seal-emblazoned carpeting of his office .
#
# Converting 0.05%:   0% 7/11950 [00:35<14:31:33,  4.38s/step]
# Converting 0.06%:   0% 7/11950 [00:39<14:31:33,  4.38s/step]
# Sentence: The plastic overlay pressed onto the map of Korea , showing the latest North and South Korean troop dispositions .
#
# Converting 0.06%:   0% 8/11950 [00:39<14:00:59,  4.23s/step]
# Converting 0.07%:   0% 8/11950 [00:42<14:00:59,  4.23s/step]
# Sentence: The light that shone indirectly on the table changed suddenly ,
#
# Converting 0.07%:   0% 9/11950 [00:42<12:06:48,  3.65s/step]
# Converting 0.08%:   0% 9/11950 [00:46<12:06:48,  3.65s/step]
# Sentence: and Thomas looked at the cabinet on the wall beside it to see "NBC News Special Bulletin" splashed across the television screen .
#
# Converting 0.08%:   0% 10/11950 [00:46<12:26:42,  3.75s/step]
# Converting 0.08%:   0% 10/11950 [00:49<12:26:42,  3.75s/step]
# Sentence: The scene switched to the White House Briefing Room for the President's address ,
#
# Converting 0.08%:   0% 11/11950 [00:49<11:45:41,  3.55s/step]
# Converting 0.09%:   0% 11/11950 [00:51<11:45:41,  3.55s/step]
# Sentence: and Thomas felt a sharp pain shoot through his jaw as he ground his teeth .
#
# Converting 0.09%:   0% 12/11950 [00:51<10:35:45,  3.20s/step]
# Converting 0.10%:   0% 12/11950 [00:55<10:35:45,  3.20s/step]
# Sentence: He had just returned from the National Security Council meeting where he had received his orders , and the frustration and anger were still fresh .
#
# Converting 0.10%:   0% 13/11950 [00:55<11:18:05,  3.41s/step]
# Converting 0.11%:   0% 13/11950 [00:59<11:18:05,  3.41s/step]
# Sentence: "Dear God . " Thomas pulled a deep and ragged sigh and sat back in his padded , oversize chair ,
#
# Converting 0.11%:   0% 14/11950 [00:59<12:11:03,  3.67s/step]
# Converting 0.12%:   0% 14/11950 [01:01<12:11:03,  3.67s/step]
# Sentence: rubbing his temples and shutting his eyes .
#
# Converting 0.12%:   0% 15/11950 [01:01<10:35:23,  3.19s/step]
# Converting 0.13%:   0% 15/11950 [01:05<10:35:23,  3.19s/step]
# Sentence: He felt a rising fear about what was coming and looked at the large wall map behind the table .
#
# Converting 0.13%:   0% 16/11950 [01:05<10:33:16,  3.18s/step]
# Converting 0.13%:   0% 16/11950 [01:08<10:33:16,  3.18s/step]
# Sentence: The blue unit markers dotting Eastern Europe were barely visible on the map . Thomas shook his head .
#
# Converting 0.13%:   0% 17/11950 [01:08<11:07:15,  3.36s/step]
# Converting 0.14%:   0% 17/11950 [01:11<11:07:15,  3.36s/step]
# Sentence: On his first tour at the Pentagon in the mid-19 80 s ,
#
# Converting 0.14%:   0% 18/11950 [01:11<10:20:58,  3.12s/step]
# Converting 0.15%:   0% 18/11950 [01:15<10:20:58,  3.12s/step]
# Sentence: the Reagan buildup had equipped them to fight two and a half wars at once - two major wars and one regional skirmish .
#
# Converting 0.15%:   0% 19/11950 [01:15<11:26:43,  3.45s/step]
# Converting 0.16%:   0% 19/11950 [01:18<11:26:43,  3.45s/step]
# Sentence: By the time of the Gulf War , the Bush Administration had scaled back to a two-war capability .
#
# Converting 0.16%:   0% 20/11950 [01:18<11:11:30,  3.38s/step]
# Converting 0.17%:   0% 20/11950 [01:21<11:11:30,  3.38s/step]
# Sentence: When he returned from his command of III Corps in southern Germany during the Clinton term ,
#
# Converting 0.17%:   0% 21/11950 [01:21<10:49:58,  3.27s/step]
# Converting 0.18%:   0% 21/11950 [01:28<10:49:58,  3.27s/step]
# Sentence: they had moved to a "win-hold-win" policy - force levels designed to win wars in succession rather than simultaneously . "Win-lose-recover ,
#
# Converting 0.18%:   0% 22/11950 [01:28<13:53:23,  4.19s/step]
# Converting 0.18%:   0% 22/11950 [01:32<13:53:23,  4.19s/step]
# Sentence: " the planners called it bitterly behind the politicos' backs . He shook his head again ; III Corps , V Corps ,
#
# Converting 0.18%:   0% 23/11950 [01:32<13:50:34,  4.18s/step]
# Converting 0.19%:   0% 23/11950 [01:36<13:50:34,  4.18s/step]
# Sentence: VII Corps - nearly all of the regular army's heavy forces and six of her ten heavy divisions on the ground in Germany ,
#
# Converting 0.19%:   0% 24/11950 [01:36<13:45:10,  4.15s/step]
# Converting 0.20%:   0% 24/11950 [01:39<13:45:10,  4.15s/step]
# Sentence: Poland , and Slovakia and of no use to him in Korea .
#
# Converting 0.20%:   0% 25/11950 [01:39<12:51:31,  3.88s/step]
# Converting 0.21%:   0% 25/11950 [01:42<12:51:31,  3.88s/step]
# Sentence: It had been a purely political decision after the military coup in Russia .
#
# Converting 0.21%:   0% 26/11950 [01:42<11:51:58,  3.58s/step]
# Converting 0.22%:   0% 26/11950 [01:45<11:51:58,  3.58s/step]
# Sentence: The secret security agreements from the Bush era with Poland and , at that time , Czechoslovakia ,
#
# Converting 0.22%:   0% 27/11950 [01:45<11:32:36,  3.49s/step]
# Converting 0.23%:   0% 27/11950 [01:49<11:32:36,  3.49s/step]
# Sentence: had forced President Livingston's hand - "put up or shut up , " Secretary of State Moore ,
#
# Converting 0.23%:   0% 28/11950 [01:49<11:30:17,  3.47s/step]
# Converting 0.23%:   0% 28/11950 [01:51<11:30:17,  3.47s/step]
# Sentence: more hawkish than any of the Joint Chiefs , had said .
#
# Converting 0.23%:   0% 29/11950 [01:51<10:44:26,  3.24s/step]
# Converting 0.24%:   0% 29/11950 [01:54<10:44:26,  3.24s/step]
# Sentence: "If you abrogate those agreements in the face of a Russian redeployment to Byelarus ,
#
# Converting 0.24%:   0% 30/11950 [01:54<10:13:47,  3.09s/step]
# Converting 0.25%:   0% 30/11950 [01:58<10:13:47,  3.09s/step]
# Sentence: there isn't a country in the world that will take us at our word when we extend our security umbrella to them . Besides ,
#
# Converting 0.25%:   0% 31/11950 [01:58<11:04:09,  3.34s/step]
# Converting 0.26%:   0% 31/11950 [02:03<11:04:09,  3.34s/step]
# Sentence: all we're talking about is a show of force . " Force , Thomas thought , that we now need somewhere else .
#
# Converting 0.26%:   0% 32/11950 [02:03<12:22:50,  3.74s/step]
# Converting 0.27%:   0% 32/11950 [02:06<12:22:50,  3.74s/step]
# Sentence: And so now , what do they want ? We told them .
#
# Converting 0.27%:   0% 33/11950 [02:06<11:46:00,  3.55s/step]
# Converting 0.28%:   0% 33/11950 [02:11<11:46:00,  3.55s/step]
# Sentence: We told Congress in the hearings what our capabilities would be at the current appropriations levels . "You heard the President ,
#
# Converting 0.28%:   0% 34/11950 [02:11<13:34:32,  4.10s/step]
# Converting 0.28%:   0% 34/11950 [02:15<13:34:32,  4.10s/step]
# Sentence: " the White House Chief of Staff Irv Waller had said at the NSC meeting earlier . "Find a way .
#
# Converting 0.28%:   0% 35/11950 [02:15<13:23:25,  4.05s/step]
# Converting 0.29%:   0% 35/11950 [02:18<13:23:25,  4.05s/step]
# Sentence: " The red light shone steadily ; his secretary had picked up the line and would get rid of the caller ,
#
# Converting 0.29%:   0% 36/11950 [02:18<12:34:44,  3.80s/step]
# Converting 0.30%:   0% 36/11950 [02:22<12:34:44,  3.80s/step]
# Sentence: probably some brass-balled reporter thinking , "I'll just call the Pentagon and ask . " As he sat in the stillness of his office ,
#
# Converting 0.30%:   0% 37/11950 [02:22<12:40:33,  3.83s/step]
# Converting 0.31%:   0% 37/11950 [02:28<12:40:33,  3.83s/step]
# Sentence: the familiar surroundings suddenly seemed alien , as if he was seeing them for the first time . The glass-enclosed cases of mementos ,
#
# Converting 0.31%:   0% 38/11950 [02:28<14:08:33,  4.27s/step]
# Converting 0.32%:   0% 38/11950 [02:31<14:08:33,  4.27s/step]
# Sentence: the unit flags with their campaign streamers , the framed commendations - they seemed to be from a life he hadn't lived .
#
# Converting 0.32%:   0% 39/11950 [02:31<13:40:10,  4.13s/step]
# Converting 0.33%:   0% 39/11950 [02:36<13:40:10,  4.13s/step]
# Sentence: It was the photographs from the distant past that began the thread that ran through all the disparate objects and linked them to the present .
#
# Converting 0.33%:   0% 40/11950 [02:36<13:55:53,  4.21s/step]
# Converting 0.33%:   0% 40/11950 [02:41<13:55:53,  4.21s/step]
# Sentence: Grainy , sloppily taken photos of grimy young men slouching under the weight of their own limbs - back from "the shit .
#
# Converting 0.33%:   0% 41/11950 [02:41<14:46:50,  4.47s/step]
# Converting 0.34%:   0% 41/11950 [02:43<14:46:50,  4.47s/step]
# Sentence: " You took pictures when you came back because you had survived ,
#
# Converting 0.34%:   0% 42/11950 [02:43<12:15:51,  3.71s/step]
# Converting 0.35%:   0% 42/11950 [02:46<12:15:51,  3.71s/step]
# Sentence: and you always took them in groups because that was the way you wanted the memories to be - always together .
#
# Converting 0.35%:   0% 43/11950 [02:46<11:44:53,  3.55s/step]
# Converting 0.36%:   0% 43/11950 [02:49<11:44:53,  3.55s/step]
# Sentence: He felt a great sadness as he looked at the succession of photos that hung on the wall ,
#
# Converting 0.36%:   0% 44/11950 [02:49<10:39:51,  3.22s/step]
# Converting 0.37%:   0% 44/11950 [02:53<10:39:51,  3.22s/step]
# Sentence: feeling each loss again as the group grew smaller . Thomas had been too tired then to feel the pain .
#
# Converting 0.37%:   0% 45/11950 [02:53<12:12:59,  3.69s/step]
# Converting 0.38%:   0% 45/11950 [02:57<12:12:59,  3.69s/step]
# Sentence: The buzz of the intercom surprised him . He looked at the phone and then poked the speaker button .
#
# Converting 0.38%:   0% 46/11950 [02:57<12:16:57,  3.71s/step]
# Converting 0.38%:   0% 46/11950 [03:01<12:16:57,  3.71s/step]
# Sentence: "I told you - no interruptions . " "Sir , I'm sorry , sir , but . . .
#
# Converting 0.38%:   0% 47/11950 [03:01<12:57:09,  3.92s/step]
# Converting 0.39%:   0% 47/11950 [03:08<12:57:09,  3.92s/step]
# Sentence: it's General Razov - on line one . " "What ? " "General Razov . . . s-someone who says he's General Razov ,
#
# Converting 0.39%:   0% 48/11950 [03:08<15:16:05,  4.62s/step]
# Converting 0.40%:   0% 48/11950 [03:11<15:16:05,  4.62s/step]
# Sentence: sir , is on line one . " Thomas's eyes focused on the photo taken the year before .
#
# Converting 0.40%:   0% 49/11950 [03:11<14:02:08,  4.25s/step]
# Converting 0.41%:   0% 49/11950 [03:14<14:02:08,  4.25s/step]
# Sentence: The charisma of Razov - the dashing hero of the first Russo-Chinese War who ,
#
# Converting 0.41%:   0% 50/11950 [03:14<12:58:04,  3.92s/step]
# Converting 0.42%:   0% 50/11950 [03:18<12:58:04,  3.92s/step]
# Sentence: at the unheard-of age of forty-six rose to command a Russian tank army with his bold ,
#
# Converting 0.42%:   0% 51/11950 [03:18<12:43:02,  3.85s/step]
# Converting 0.43%:   0% 51/11950 [03:22<12:43:02,  3.85s/step]
# Sentence: slashing drives into the flanks of the Chinese attack - shone brightly through the glass cover . And Thomas ,
#
# Converting 0.43%:   0% 52/11950 [03:22<12:40:07,  3.83s/step]
# Converting 0.44%:   0% 52/11950 [03:25<12:40:07,  3.83s/step]
# Sentence: graying and tired but jubilant over the younger man's string of stunning victories for which Thomas secretly ,
#
# Converting 0.44%:   0% 53/11950 [03:25<12:28:40,  3.78s/step]
# Converting 0.44%:   0% 53/11950 [03:29<12:28:40,  3.78s/step]
# Sentence: inwardly felt some measure of shared pride after near constant counsel during the forty days and nights of the war .
#
# Converting 0.44%:   0% 54/11950 [03:29<12:37:44,  3.82s/step]
# Converting 0.45%:   0% 54/11950 [03:32<12:37:44,  3.82s/step]
# Sentence: "Get the duty officer up here on the double , " he ordered , "and trace the call . " "Yes , sir .
#
# Converting 0.45%:   0% 55/11950 [03:32<11:59:43,  3.63s/step]
# Converting 0.46%:   0% 55/11950 [03:37<11:59:43,  3.63s/step]
# Sentence: " Thomas rested his finger atop the button on the telephone . The blinking light shone blood red through his fingernail .
#
# Converting 0.46%:   0% 56/11950 [03:37<12:51:40,  3.89s/step]
# Converting 0.47%:   0% 56/11950 [03:41<12:51:40,  3.89s/step]
# Sentence: He rubbed the smooth plastic for a second and then pushed . "Who the hell is this ? " he asked loudly ,
#
# Converting 0.47%:   0% 57/11950 [03:41<13:06:07,  3.97s/step]
# Converting 0.48%:   0% 57/11950 [03:45<13:06:07,  3.97s/step]
# Sentence: anticipating the laughter of an old classmate from the Point with a poor sense of timing and humor .
#
# Converting 0.48%:   0% 58/11950 [03:45<12:30:22,  3.79s/step]
# Converting 0.49%:   0% 58/11950 [03:50<12:30:22,  3.79s/step]
# Sentence: "I am General Yuri Vladimirovich Razov , commander of Far Eastern Military District of Republic of Russia . " Thomas was stunned . "Hello ,
#
# Converting 0.49%:   0% 59/11950 [03:50<14:18:32,  4.33s/step]
# Converting 0.49%:   0% 59/11950 [03:55<14:18:32,  4.33s/step]
# Sentence: Andr-rusha . " The faint white noise in the background hinted at the distance of the source . "Yuri ? " "Yes ,
#
# Converting 0.49%:   1% 60/11950 [03:55<14:57:49,  4.53s/step]
# Converting 0.50%:   1% 60/11950 [04:00<14:57:49,  4.53s/step]
# Sentence: Andrushenka" came the response , again after a pause - a satellite transmission delay . "What . . . ? " Thomas began ,
#
# Converting 0.50%:   1% 61/11950 [04:00<14:54:37,  4.51s/step]
# Converting 0.51%:   1% 61/11950 [04:04<14:54:37,  4.51s/step]
# Sentence: but found himself at a loss . "Andrew , I am calling you with very regrettable news , " the man said ,
#
# Converting 0.51%:   1% 62/11950 [04:04<14:30:50,  4.40s/step]
# Converting 0.52%:   1% 62/11950 [04:09<14:30:50,  4.40s/step]
# Sentence: his words slightly slurred as if by liquor , although Thomas knew that would not be the case . He sounds exhausted ,
#
# Converting 0.52%:   1% 63/11950 [04:09<14:55:56,  4.52s/step]
# Converting 0.53%:   1% 63/11950 [04:13<14:55:56,  4.52s/step]
# Sentence: Thomas thought as he flicked a small switch on the side of his phone . A yellow light next to the word TAPING came on .
#
# Converting 0.53%:   1% 64/11950 [04:13<14:30:37,  4.39s/step]
# Converting 0.54%:   1% 64/11950 [04:18<14:30:37,  4.39s/step]
# Sentence: "Go ahead , " he said guardedly . "We have taken our strategic rocket and ballistic missile submarine forces from 'Constant' to 'Increased' alert status .
#
# Converting 0.54%:   1% 65/11950 [04:18<15:22:09,  4.66s/step]
# Converting 0.54%:   1% 65/11950 [04:21<15:22:09,  4.66s/step]
# Sentence: Your next satellite pass should confirm that . In addition ,
#
# Converting 0.54%:   1% 66/11950 [04:21<13:49:17,  4.19s/step]
# Converting 0.55%:   1% 66/11950 [04:25<13:49:17,  4.19s/step]
# Sentence: the Svobodnyy Missile Field in the Far East has gone all the way up to 'Maximum' alert . " Razov paused ,
#
# Converting 0.55%:   1% 67/11950 [04:25<13:24:37,  4.06s/step]
# Converting 0.56%:   1% 67/11950 [04:27<13:24:37,  4.06s/step]
# Sentence: and time seemed to stand still . "In less than half an hour ,
#
# Converting 0.56%:   1% 68/11950 [04:27<11:59:11,  3.63s/step]
# Converting 0.57%:   1% 68/11950 [04:32<11:59:11,  3.63s/step]
# Sentence: my heavy artillery and rocket forces will strike fourteen tactical targets along our front in Occupied Northern China with nuclear weapons .
#
# Converting 0.57%:   1% 69/11950 [04:32<13:21:43,  4.05s/step]
# Converting 0.58%:   1% 69/11950 [04:37<13:21:43,  4.05s/step]
# Sentence: We plan to lay open holes through which we will launch counterattacks intended to stabilize our lines . In order to avoid risking escalation ,
#
# Converting 0.58%:   1% 70/11950 [04:37<13:33:14,  4.11s/step]
# Converting 0.59%:   1% 70/11950 [04:41<13:33:14,  4.11s/step]
# Sentence: we will of course have to neutralize the Chinese strategic forces . " "Yuri , " Thomas said as his mind reeled ,
#
# Converting 0.59%:   1% 71/11950 [04:41<13:50:38,  4.20s/step]
# Converting 0.59%:   1% 71/11950 [04:45<13:50:38,  4.20s/step]
# Sentence: "in God's name you can't do this . " A shiver went up his chest as a box , long ago closed ,
#
# Converting 0.59%:   1% 72/11950 [04:45<13:57:25,  4.23s/step]
# Converting 0.60%:   1% 72/11950 [04:48<13:57:25,  4.23s/step]
# Sentence: opened suddenly to release its demons . "We will do it , but not in God's name .
#
# Converting 0.60%:   1% 73/11950 [04:48<12:42:25,  3.85s/step]
# Converting 0.61%:   1% 73/11950 [04:52<12:42:25,  3.85s/step]
# Sentence: " "No" was all Thomas could think to say . "No ! Yuri , if the Chinese get a shot off . . . !
#
# Converting 0.61%:   1% 74/11950 [04:52<12:21:52,  3.75s/step]
# Converting 0.62%:   1% 74/11950 [04:56<12:21:52,  3.75s/step]
# Sentence: " "You know as well as I that the Chinese have only four operational T-4 s capable of reaching our European populations .
#
# Converting 0.62%:   1% 75/11950 [04:56<12:29:48,  3.79s/step]
# Converting 0.63%:   1% 75/11950 [05:00<12:29:48,  3.79s/step]
# Sentence: We will strike their T-3 s , T-2 s and T-1 s plus their submarines and B-6 bomber bases ,
#
# Converting 0.63%:   1% 76/11950 [05:00<13:02:02,  3.95s/step]
# Converting 0.64%:   1% 76/11950 [05:05<13:02:02,  3.95s/step]
# Sentence: but once we knock out the T-4 s they will be unable to threaten us strategically . " "They could still get a shot off !
#
# Converting 0.64%:   1% 77/11950 [05:05<13:37:04,  4.13s/step]
# Converting 0.64%:   1% 77/11950 [05:10<13:37:04,  4.13s/step]
# Sentence: " "Their land-based missiles are all liquid fueled - nitrogen tetroxide as the oxidizer and unsymmetrical dimethylhydrazine as the fuel .
#
# Converting 0.64%:   1% 78/11950 [05:10<14:42:58,  4.46s/step]
# Converting 0.65%:   1% 78/11950 [05:13<14:42:58,  4.46s/step]
# Sentence: You know what those liquids' corrosive effects do to the fuel tanks . Plus there are the evaporation rates .
#
# Converting 0.65%:   1% 79/11950 [05:13<13:43:52,  4.16s/step]
# Converting 0.66%:   1% 79/11950 [05:16<13:43:52,  4.16s/step]
# Sentence: We have shared the intelligence , Andrusha , and I know your conclusions correspond to our own .
#
# Converting 0.66%:   1% 80/11950 [05:16<12:34:11,  3.81s/step]
# Converting 0.67%:   1% 80/11950 [05:20<12:34:11,  3.81s/step]
# Sentence: Those missiles remain dry until prelaunch sequencing , and ever since we knocked their satellites down in the last war ,
#
# Converting 0.67%:   1% 81/11950 [05:20<12:42:24,  3.85s/step]
# Converting 0.68%:   1% 81/11950 [05:23<12:42:24,  3.85s/step]
# Sentence: they have had no technical means of monitoring our launches . Therefore ,
#
# Converting 0.68%:   1% 82/11950 [05:23<12:02:48,  3.65s/step]
# Converting 0.69%:   1% 82/11950 [05:28<12:02:48,  3.65s/step]
# Sentence: they won't have any warning until the reentry vehicles hit the upper atmosphere and ablation releases enough reflective material to return a radar signature .
#
# Converting 0.69%:   1% 83/11950 [05:28<12:55:11,  3.92s/step]
# Converting 0.69%:   1% 83/11950 [05:32<12:55:11,  3.92s/step]
# Sentence: That would be no more than twenty to thirty seconds before detonation - not nearly enough time to fuel .
#
# Converting 0.69%:   1% 84/11950 [05:32<12:37:19,  3.83s/step]
# Converting 0.70%:   1% 84/11950 [05:34<12:37:19,  3.83s/step]
# Sentence: " "You can't do this , Yuri , " Thomas said ,
#
# Converting 0.70%:   1% 85/11950 [05:34<11:27:18,  3.48s/step]
# Converting 0.71%:   1% 85/11950 [05:37<11:27:18,  3.48s/step]
# Sentence: pressing his thumb into his ear as he sat hunched over his desk ,
#
# Converting 0.71%:   1% 86/11950 [05:37<10:20:20,  3.14s/step]
# Converting 0.72%:   1% 86/11950 [05:39<10:20:20,  3.14s/step]
# Sentence: staring off into space as thoughts began to fly like sparks through his mind ,
#
# Converting 0.72%:   1% 87/11950 [05:39<9:51:43,  2.99s/step]
# Converting 0.73%:   1% 87/11950 [05:44<9:51:43,  2.99s/step]
# Sentence: fears lit by the sparks beginning fires that consumed all other worries . "Are you ready to hear the rest ? " Razov asked ,
#
# Converting 0.73%:   1% 88/11950 [05:44<11:50:08,  3.59s/step]
# Converting 0.74%:   1% 88/11950 [05:50<11:50:08,  3.59s/step]
# Sentence: and Thomas pulled out a pencil and note pad . "Our Strategic Rocket Forces will fire nineteen missiles of the type you have named SS-19,
#
# Converting 0.74%:   1% 89/11950 [05:50<13:35:01,  4.12s/step]
# Converting 0.74%:   1% 89/11950 [05:52<13:35:01,  4.12s/step]
# Sentence: with the possibility of a small number more in a restrike within less than an hour's time .
#
# Converting 0.74%:   1% 90/11950 [05:52<12:17:36,  3.73s/step]
# Converting 0.75%:   1% 90/11950 [05:56<12:17:36,  3.73s/step]
# Sentence: The missiles will deploy one hundred sixty-nine war-heads . " Thomas wrote the numbers down .
#
# Converting 0.75%:   1% 91/11950 [05:56<12:04:03,  3.66s/step]
# Converting 0.76%:   1% 91/11950 [06:00<12:04:03,  3.66s/step]
# Sentence: "All will be fired exclusively from the Far Eastern Military District . None , I repeat , none ,
#
# Converting 0.76%:   1% 92/11950 [06:00<12:43:24,  3.86s/step]
# Converting 0.77%:   1% 92/11950 [06:04<12:43:24,  3.86s/step]
# Sentence: of these missiles will in any way threaten the United States or any of her allies . " "The hell they won't , Yuri !
#
# Converting 0.77%:   1% 93/11950 [06:04<12:38:24,  3.84s/step]
# Converting 0.78%:   1% 93/11950 [06:08<12:38:24,  3.84s/step]
# Sentence: This is insane ! You can't do this ! " Thomas noted the time on his watch and wrote that on his pad also .
#
# Converting 0.78%:   1% 94/11950 [06:08<13:11:08,  4.00s/step]
# Converting 0.79%:   1% 94/11950 [06:11<13:11:08,  4.00s/step]
# Sentence: His secretary stuck his head in the door , his own phone to his ear .
#
# Converting 0.79%:   1% 95/11950 [06:11<12:14:26,  3.72s/step]
# Converting 0.79%:   1% 95/11950 [06:14<12:14:26,  3.72s/step]
# Sentence: Thomas jabbed his finger at the mouthpiece of the telephone's handset ,
#
# Converting 0.79%:   1% 96/11950 [06:14<10:57:19,  3.33s/step]
# Converting 0.80%:   1% 96/11950 [06:18<10:57:19,  3.33s/step]
# Sentence: and his secretary rolled his finger in the air and pointed at his watch before returning to his desk . Thomas had to stall .
#
# Converting 0.80%:   1% 97/11950 [06:18<11:36:19,  3.52s/step]
# Converting 0.81%:   1% 97/11950 [06:23<11:36:19,  3.52s/step]
# Sentence: "Listen to me , Yuri . I'm warning you , something will go wrong . Something always goes wrong ! You know that !
#
# Converting 0.81%:   1% 98/11950 [06:23<13:03:13,  3.97s/step]
# Converting 0.82%:   1% 98/11950 [06:26<13:03:13,  3.97s/step]
# Sentence: Your plans - they demand perfection . They're brittle .
#
# Converting 0.82%:   1% 99/11950 [06:26<12:35:40,  3.83s/step]
# Converting 0.83%:   1% 99/11950 [06:29<12:35:40,  3.83s/step]
# Sentence: What if the Chinese have seen your ground troops maneuvering to hit spots on their line that make no sense ,
#
# Converting 0.83%:   1% 100/11950 [06:29<11:50:49,  3.60s/step]
# Converting 0.84%:   1% 100/11950 [06:33<11:50:49,  3.60s/step]
# Sentence: and they've put two and two together and gone to a higher alert status ? What if there's a leak ? " "As usual ,
#
# Converting 0.84%:   1% 101/11950 [06:33<12:07:02,  3.68s/step]
# Converting 0.85%:   1% 101/11950 [06:38<12:07:02,  3.68s/step]
# Sentence: " Razov said with a hint of amusement , "you sound like the prophet of doom . The Chinese are not on higher alert .
#
# Converting 0.85%:   1% 102/11950 [06:38<13:07:07,  3.99s/step]
# Converting 0.85%:   1% 102/11950 [06:41<13:07:07,  3.99s/step]
# Sentence: We have confirmed that by technical means . And I can assure you , Andrew ,
#
# Converting 0.85%:   1% 103/11950 [06:41<12:15:11,  3.72s/step]
# Converting 0.86%:   1% 103/11950 [06:45<12:15:11,  3.72s/step]
# Sentence: that our plans are the most highly guarded secret in Russia today . We have an automated firing system , as you know ,
#
# Converting 0.86%:   1% 104/11950 [06:45<12:15:17,  3.72s/step]
# Converting 0.87%:   1% 104/11950 [06:47<12:15:17,  3.72s/step]
# Sentence: not launch crews as in your system .
#
# Converting 0.87%:   1% 105/11950 [06:47<10:34:33,  3.21s/step]
# Converting 0.88%:   1% 105/11950 [06:51<10:34:33,  3.21s/step]
# Sentence: The only people who know of the plan are the principals of the Supreme High Command at STAVKA who authorized it ,
#
# Converting 0.88%:   1% 106/11950 [06:51<11:20:32,  3.45s/step]
# Converting 0.89%:   1% 106/11950 [06:55<11:20:32,  3.45s/step]
# Sentence: the two officers manning STAVKA's nuclear communicators , and my aide and two army commanders , who drew up the plan here in Khabarovsk .
#
# Converting 0.89%:   1% 107/11950 [06:55<12:09:50,  3.70s/step]
# Converting 0.90%:   1% 107/11950 [06:59<12:09:50,  3.70s/step]
# Sentence: There is no way that they will get off a shot , Andrew . It is impossible . " Thomas's secretary reappeared ,
#
# Converting 0.90%:   1% 108/11950 [06:59<12:29:55,  3.80s/step]
# Converting 0.90%:   1% 108/11950 [07:03<12:29:55,  3.80s/step]
# Sentence: and Thomas muted the telephone . "They're tracing , sir , but it'll take - " "Get the President on the line now !
#
# Converting 0.90%:   1% 109/11950 [07:03<12:57:57,  3.94s/step]
# Converting 0.91%:   1% 109/11950 [07:09<12:57:57,  3.94s/step]
# Sentence: Emergency telephone conference ! Then I want telephonic missile threat , missile warning system , and significant event conferences - in that order !
#
# Converting 0.91%:   1% 110/11950 [07:09<14:43:54,  4.48s/step]
# Converting 0.92%:   1% 110/11950 [07:14<14:43:54,  4.48s/step]
# Sentence: " The secretary's eyes widened and he turned from the doorway to lunge for his desk . Thomas released the MUTE button . "Yuri ,
#
# Converting 0.92%:   1% 111/11950 [07:14<15:07:54,  4.60s/step]
# Converting 0.93%:   1% 111/11950 [07:18<15:07:54,  4.60s/step]
# Sentence: nothing is impossible . " He closed his eyes and focused his attention on the phone , on the man at the other end .
#
# Converting 0.93%:   1% 112/11950 [07:18<14:25:12,  4.39s/step]
